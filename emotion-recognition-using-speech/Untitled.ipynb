# %%
from emotion_recognition import EmotionRecognizer
from sklearn.svm import SVC
from deep_emotion_recognition import DeepEmotionRecognizer
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0813 10:54:21.585338 140735684912000 deprecation_wrapper.py:119] From /Users/m.elabd/Desktop/last_hope/emotion-recognition-using-speech/deep_emotion_recognition.py:15: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
# init a model, let's use SVC
my_model = SVC()
# pass my model to EmotionRecognizer instance
# and balance the dataset
rec = EmotionRecognizer(model=my_model, emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'], balance=True, verbose=0)
# train the model
rec.train()
# check the test accuracy for that model
print("Test score:", rec.test_score())
# check the train accuracy for that model
print("Train score:", rec.train_score())
# Out:
# ...
# Extracting features for test: 100%|██████████| 967/967 [00:47<00:00, 20.22it/s]
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [+] Model trained
# Test score: 0.7326007326007326
# Train score: 0.9993906154783668

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['angry', 'sad', 'neutral', 'ps', 'happy'], n_rnn_layers=2, n_dense_layers=2, rnn_units=128, dense_units=128)
# train the model
deeprec.train()
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# W0812 14:49:36.348868 140736221422464 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0812 14:49:36.373715 140736221422464 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0812 14:49:36.382452 140736221422464 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'], n_rnn_layers=3, n_dense_layers=2, rnn_units=128, dense_units=128,
                               epochs=500)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'],
                                n_rnn_layers=2, n_dense_layers=3, rnn_units=128, dense_units=128,
                                dropout=0.35,epochs=500)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'],
                                n_rnn_layers=2, n_dense_layers=3, rnn_units=256, dense_units=128,
                                dropout=0.35,epochs=500)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'],
                                n_rnn_layers=2, n_dense_layers=3, rnn_units=128, dense_units=256,
                                dropout=0.35,epochs=500)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'],
                                n_rnn_layers=3, n_dense_layers=3, rnn_units=128, dense_units=256,
                                dropout=0.42,epochs=500)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'],
                                n_rnn_layers=2, n_dense_layers=2, rnn_units=128, dense_units=256,
                                dropout=0.42,epochs=500, batch_size=256)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...

# %%
# initialize instance
# inherited from emotion_recognition.EmotionRecognizer
# default parameters (LSTM: 128x2, Dense:128x2)
deeprec = DeepEmotionRecognizer(emotions=['sad', 'neutral', 'happy', 'angry', 'disgust', 'fear'],
                                n_rnn_layers=2, n_dense_layers=4, rnn_units=256, dense_units=128,
                                dropout=0.38,epochs=500, batch_size=512)
# train the model
deeprec.train(override=True)
# get the accuracy
print(deeprec.test_score())
# predict angry audio sample
prediction = deeprec.predict('data/validation/Actor_10/03-02-05-02-02-02-10_angry.wav')
print(f"Prediction: {prediction}")
# Out:
# [TESS&RAVDESS] There are 812 training audio files for category:sad
# [TESS&RAVDESS] There are 146 testing audio files for category:sad
# [TESS&RAVDESS] There are 585 training audio files for category:neutral
# [TESS&RAVDESS] There are 93 testing audio files for category:neutral
# [TESS&RAVDESS] There are 805 training audio files for category:happy
# [TESS&RAVDESS] There are 147 testing audio files for category:happy
# [TESS&RAVDESS] There are 808 training audio files for category:angry
# [TESS&RAVDESS] There are 147 testing audio files for category:angry
# [TESS&RAVDESS] There are 511 training audio files for category:disgust
# [TESS&RAVDESS] There are 79 testing audio files for category:disgust
# [TESS&RAVDESS] There are 817 training audio files for category:fear
# [TESS&RAVDESS] There are 141 testing audio files for category:fear
# [+] Writed TESS & RAVDESS DB CSV File
# [EMO-DB] Total files to write: 454
# [EMO-DB] Training samples: 363
# [EMO-DB] Testing samples: 90
# ...
